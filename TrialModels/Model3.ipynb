# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Load dataset

# %%
# Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

csv_files = [
    # 'dataset/users_final_games1.csv',
    'dataset/users_final_games2.csv',
    # 'dataset/users_final_games3.csv'
]

dfs = []

for file in csv_files:
    df = pd.read_csv(file)
    # df = pd.read_csv(file, header=None)
    dfs.append(df)

# Concatenate all CSVs
combined_df = pd.concat(dfs, ignore_index=True)

combined_df.columns = [
    "ID",
    "PlayerID",
    "GameID",
    "GameName",
    "GameGenre",
    "RunID",
    "RunTime",
    "CategoryType",
    "PlayerCountry",
    "PlayerPronouns",
    "PlayerSignupDate"
]

combined_df.head()
# Out:
#    ID    PlayerID    GameID                     GameName      GameGenre  \
# 0   1  j52v6ozj\n  o1y9j9v6                      Celeste  2D Platformer
# 1   2  j52v6ozj\n  46w3xrq1                 Tetris (Web)            NaN
# 2   3  j52v6ozj\n  46w3xrq1                 Tetris (Web)            NaN
# 3   4  j52v6ozj\n  j1ne9me1  Celeste Category Extensions  2D Platformer
# 4   5  8ge97w1j\n  o1y9j9v6                      Celeste  2D Platformer
#
#       RunID   RunTime CategoryType PlayerCountry PlayerPronouns  \
# 0  mrx9177m  2605.743     per-game      Scotland        She/Her
# 1  y6xkwe6y    17.433     per-game      Scotland        She/Her
# 2  z0porq9y    33.000     per-game      Scotland        She/Her
# 3  z52v70nz    29.818     per-game      Scotland        She/Her
# 4  yv2rn9em  2894.811     per-game           NaN            NaN
#
#        PlayerSignupDate
# 0  2022-04-22T20:41:25Z
# 1  2022-04-22T20:41:25Z
# 2  2022-04-22T20:41:25Z
# 3  2022-04-22T20:41:25Z
# 4  2020-06-24T18:09:48Z

# %% [markdown]
# ## Collaborative Filtering

# %% [markdown]
# ### Player-Game Matrix

# %%
# Build player-game interaction matrix (show which players ran which games)
player_game_matrix = combined_df.pivot_table(
    index='PlayerID',
    columns='GameName',
    values='RunID',
    aggfunc='count',  # Count how many runs player did per game
    fill_value=0
)

# Turn into binary matrix (1 = played at least once, 0 = never)
player_game_matrix = player_game_matrix.applymap(lambda x: 1 if x > 0 else 0)

player_game_matrix.head()
# Out:
# C:\Users\halim\AppData\Local\Temp\ipykernel_29332\2420552543.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   player_game_matrix = player_game_matrix.applymap(lambda x: 1 if x > 0 else 0)
# GameName     Non-Euclidean Lemon Grab Experiment  \
# PlayerID
# 0jm02o81\n                                     0
# 0jm050y8\n                                     0
# 0jm0d448\n                                     0
# 0jm0my81\n                                     0
# 0jm0ple8\n                                     0
#
# GameName     Stories of Nibel: Tale of Ura  ! Fishy !  !findseed the map  \
# PlayerID
# 0jm02o81\n                               0          0                  0
# 0jm050y8\n                               0          0                  0
# 0jm0d448\n                               0          0                  0
# 0jm0my81\n                               0          0                  0
# 0jm0ple8\n                               0          0                  0
#
# GameName    (Deltarune Chapter 3) - Mike's Big Showdown  \
# PlayerID
# 0jm02o81\n                                            0
# 0jm050y8\n                                            0
# 0jm0d448\n                                            0
# 0jm0my81\n                                            0
# 0jm0ple8\n                                            0
#
# GameName    (Scratch) Undieable Appel  \
# PlayerID
# 0jm02o81\n                          0
# 0jm050y8\n                          0
# 0jm0d448\n                          0
# 0jm0my81\n                          0
# 0jm0ple8\n                          0
#
# GameName    *NEW* SCUFFED BHOP SIMULATION 2026 GOTY EDITION  - Pixel Sheep -  \
# PlayerID
# 0jm02o81\n                                                0                0
# 0jm050y8\n                                                0                0
# 0jm0d448\n                                                0                0
# 0jm0my81\n                                                0                0
# 0jm0ple8\n                                                0                0
#
# GameName    -Easy-  -SPROUT-  ...  territorial.io  \
# PlayerID                      ...
# 0jm02o81\n       0         0  ...               0
# 0jm050y8\n       0         0  ...               0
# 0jm0d448\n       0         0  ...               0
# 0jm0my81\n       0         0  ...               0
# 0jm0ple8\n       0         0  ...               0
#
# GameName    the official sequel to Five Nights at Cragdor's  vivid/stasis  \
# PlayerID
# 0jm02o81\n                                                0             0
# 0jm050y8\n                                                0             0
# 0jm0d448\n                                                0             0
# 0jm0my81\n                                                0             0
# 0jm0ple8\n                                                0             0
#
# GameName    vridniX  willo  xkcd: Hoverboard  yet another 2d platformer  \
# PlayerID
# 0jm02o81\n        0      0                 0                          0
# 0jm050y8\n        0      0                 0                          0
# 0jm0d448\n        0      0                 0                          0
# 0jm0my81\n        0      0                 0                          0
# 0jm0ple8\n        0      0                 0                          0
#
# GameName    • CONNECTION  天神怪戦（Mercenary Force）  暖雪 Warm Snow
# PlayerID
# 0jm02o81\n             0                      0             0
# 0jm050y8\n             0                      0             0
# 0jm0d448\n             0                      0             0
# 0jm0my81\n             0                      0             0
# 0jm0ple8\n             0                      0             0
#
# [5 rows x 9111 columns]

# %% [markdown]
# ### Train/Test Splitting

# %%
def train_test_split_player_game_matrix(player_game_matrix, test_fraction=0.2):
    train = player_game_matrix.copy()
    test = {}

    for player in player_game_matrix.index:
        played_games = player_game_matrix.columns[player_game_matrix.loc[player] == 1]
        if len(played_games) > 1:  # Only split players who played multiple games
            test_games = np.random.choice(played_games, size=max(1, int(len(played_games) * test_fraction)), replace=False)
            for game in test_games:
                train.at[player, game] = 0  # Mask this game in train
            test[player] = test_games

    return train, test

# %%
train_matrix, test_dict = train_test_split_player_game_matrix(player_game_matrix, test_fraction=0.2)

train_matrix_sparse = csr_matrix(train_matrix.values)

# %% [markdown]
# ## Model Training

# %%
# Sample 2000 players randomly
# sampled_players = train_matrix.sample(n=2000, random_state=42)

player_sim_df_train = pd.DataFrame(
    # cosine_similarity(sampled_players), # Compute similarity for sampled players instead of entire train_matrix
    # index=sampled_players.index,
    # columns=sampled_players.index

    cosine_similarity(train_matrix_sparse),
    index=train_matrix.index,
    columns=train_matrix.index
)

player_sim_df_train.head()
# Out:
# PlayerID    0jm002y8\n  0jm00348\n  0jm01yo8\n  0jm02o81\n  0jm04481\n  \
# PlayerID
# 0jm002y8\n    1.000000    0.000000    0.408248    0.316228    0.000000
# 0jm00348\n    0.000000    1.000000    0.000000    0.000000    0.408248
# 0jm01yo8\n    0.408248    0.000000    1.000000    0.258199    0.000000
# 0jm02o81\n    0.316228    0.000000    0.258199    1.000000    0.000000
# 0jm04481\n    0.000000    0.408248    0.000000    0.000000    1.000000
#
# PlayerID    0jm050y8\n  0jm05ry8\n  0jm09qy8\n  0jm0d448\n  0jm0my81\n  ...  \
# PlayerID                                                                ...
# 0jm002y8\n         0.0    0.707107    1.000000         0.0         0.0  ...
# 0jm00348\n         0.0    0.000000    0.000000         0.0         0.0  ...
# 0jm01yo8\n         0.0    0.288675    0.408248         0.0         0.0  ...
# 0jm02o81\n         0.0    0.223607    0.316228         0.0         0.0  ...
# 0jm04481\n         0.0    0.000000    0.000000         0.0         0.0  ...
#
# PlayerID    zxzze9xq\n  zxzzem4x\n  zxzzmw9x\n  zxzzpgnx\n  zxzzrorx\n  \
# PlayerID
# 0jm002y8\n    0.377964         0.0    1.000000    0.500000         0.0
# 0jm00348\n    0.000000         0.0    0.000000    0.000000         0.0
# 0jm01yo8\n    0.154303         0.0    0.408248    0.204124         0.0
# 0jm02o81\n    0.119523         0.0    0.316228    0.158114         0.0
# 0jm04481\n    0.000000         0.0    0.000000    0.000000         0.0
#
# PlayerID    zxzzyd4x\n  zxzzygex\n  zxzzyk4x\n  zxzzyvnx\n  zxzzzrxq\n
# PlayerID
# 0jm002y8\n    1.000000         0.0    1.000000    0.000000    0.377964
# 0jm00348\n    0.000000         0.0    0.000000    0.707107    0.000000
# 0jm01yo8\n    0.408248         0.0    0.408248    0.000000    0.154303
# 0jm02o81\n    0.316228         0.0    0.316228    0.000000    0.358569
# 0jm04481\n    0.000000         0.0    0.000000    0.577350    0.000000
#
# [5 rows x 29791 columns]

# %% [markdown]
# ## Recommender Function

# %%
def recommend_games_for_player(player_id, player_game_matrix, player_sim_df, top_n=5):
    # 1. Get the similarity scores for the player
    similar_players = player_sim_df[player_id].sort_values(ascending=False)
    similar_players = similar_players.drop(player_id)  # Remove self

    # 2. Get games the player hasn't played yet
    player_games = player_game_matrix.loc[player_id]
    games_not_played = player_games[player_games == 0].index.tolist()

    # 3. Score unplayed games based on similar players
    game_scores = {}
    for sim_player_id, similarity_score in similar_players.items():
        sim_player_games = player_game_matrix.loc[sim_player_id]
        for game in games_not_played:
            if sim_player_games[game] > 0:
                game_scores[game] = game_scores.get(game, 0) + similarity_score

    # 4. Sort and recommend
    sorted_games = sorted(game_scores.items(), key=lambda x: x[1], reverse=True)
    recommended_games = [game for game, score in sorted_games[:top_n]]

    return recommended_games

# %%
# recommend_games_for_player(player_id='xymr52yx\n',
#                             player_game_matrix=player_game_matrix,
#                             player_sim_df=player_sim_df_train,
#                             top_n=5)

# %% [markdown]
# ## Evaluation Metrics

# %%
import random

def dcg_at_k(ranked_list, true_items, k):
    """Compute Discounted Cumulative Gain at rank K"""
    dcg = 0.0
    for i in range(k):
        if ranked_list[i] in true_items:
            dcg += 1 / np.log2(i + 2)  # log2(rank+1)
    return dcg

def ndcg_at_k(ranked_list, true_items, k):
    """Compute Normalized DCG"""
    dcg = dcg_at_k(ranked_list, true_items, k)
    # Ideal DCG = best case where relevant items are ranked first
    ideal_dcg = sum(1 / np.log2(i + 2) for i in range(min(len(true_items), k)))
    if ideal_dcg == 0:
        return 0.0
    return dcg / ideal_dcg

# Sample 300 players from test_dict
# sampled_players = random.sample(list(test_dict.keys()), k=8)

def evaluate_recommender(player_game_matrix, player_sim_df, test_dict, top_n=5, sampled_players=None):
    hits = 0
    total = 0
    precision_total = 0
    ndcg_total = 0

    players = sampled_players if sampled_players is not None else test_dict.keys()

    for player in players:
        true_games = test_dict[player]
        if player not in player_sim_df.index:
            continue

        recs = recommend_games_for_player(player, player_game_matrix, player_sim_df, top_n)

        hit = any(game in recs for game in true_games)
        hits += int(hit)

        precision = len(set(recs) & set(true_games)) / len(recs)
        precision_total += precision

        ndcg = ndcg_at_k(recs, true_games, top_n)
        ndcg_total += ndcg

        total += 1

    hit_rate = hits / total
    avg_precision = precision_total / total
    avg_ndcg = ndcg_total / total

    return hit_rate, avg_precision, avg_ndcg

# %%
hit_rate, avg_precision, avg_ndcg = evaluate_recommender(
    player_game_matrix=train_matrix,
    player_sim_df=player_sim_df_train,
    test_dict=test_dict,
    top_n=5,
    # sampled_players=sampled_players
)

print(f"Hit Rate: {hit_rate:.6f}")
print(f"Average Precision: {avg_precision:.6f}")
print(f"Average NDCG: {avg_ndcg:.6f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 hit_rate, avg_precision, avg_ndcg = evaluate_recommender(
#       2     player_game_matrix=train_matrix,
#       3     player_sim_df=player_sim_df_train,
#       4     test_dict=test_dict,
#       5     top_n=5,
#       6     # sampled_players=sampled_players
#       7 )
#       9 print(f"Hit Rate: {hit_rate:.6f}")
#      10 print(f"Average Precision: {avg_precision:.6f}")
#
# Cell In[16], line 36, in evaluate_recommender(player_game_matrix, player_sim_df, test_dict, top_n, sampled_players)
#      33 if player not in player_sim_df.index:
#      34     continue
# ---> 36 recs = recommend_games_for_player(player, player_game_matrix, player_sim_df, top_n)
#      38 hit = any(game in recs for game in true_games)
#      39 hits += int(hit)
#
# Cell In[15], line 15, in recommend_games_for_player(player_id, player_game_matrix, player_sim_df, top_n)
#      13     sim_player_games = player_game_matrix.loc[sim_player_id]
#      14     for game in games_not_played:
# ---> 15         if sim_player_games[game] > 0:
#      16             game_scores[game] = game_scores.get(game, 0) + similarity_score
#      18 # 4. Sort and recommend
#
# File c:\Users\halim\miniconda3\envs\tf-cpu\lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\halim\miniconda3\envs\tf-cpu\lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\halim\miniconda3\envs\tf-cpu\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3803 casted_key = self._maybe_cast_indexer(key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#
# KeyboardInterrupt:

# %% [markdown]
# Hit Rate@5: 0.52
# Out of all players, 52% had at least one of their games correctly recommended in their top 5 suggestions.
#
# Precision@5: 0.10
# On average, 10% of the top 5 recommendations were actually correct.
#
# NDCG
# 0.5–0.7 NDCG is good for recommenders.
#
# Value	      Meaning
# ~1.0	      Perfect ranking (ideal)
# ~0.5	     	Some relevant games appear but not always at the top
# ~0.0		    Bad ranking (random guessing)

# %% [markdown]
# ## Content-Based Filtering

# %% [markdown]
# ### Game Feature Vectors

# %%
# 1. Calculate the average run time for each game
avg_run_time = combined_df.groupby('GameName')['RunTime'].mean()

# 2. One-hot encode game genres
genre_dummies = pd.get_dummies(combined_df[['GameName', 'GameGenre']].drop_duplicates().set_index('GameName'))

# 3. Merge into one game feature matrix
game_features = genre_dummies.join(avg_run_time)

# Fill missing values if any
game_features = game_features.fillna(0)

game_features.head()
# Out:
#                                  GameGenre_2D  GameGenre_2D Platformer  \
# GameName
# ULTRAKILL                               False                    False
# ROBLOX: Tower Defense Simulator         False                    False
# Sonic Forces                            False                    False
# Unbothered                              False                    False
# Piano Tiles (Scratch)                   False                    False
#
#                                  GameGenre_3D  GameGenre_3D Platformer  \
# GameName
# ULTRAKILL                               False                    False
# ROBLOX: Tower Defense Simulator         False                    False
# Sonic Forces                            False                    False
# Unbothered                              False                    False
# Piano Tiles (Scratch)                   False                    False
#
#                                  GameGenre_Action  GameGenre_Action Adventure  \
# GameName
# ULTRAKILL                                   False                       False
# ROBLOX: Tower Defense Simulator             False                       False
# Sonic Forces                                 True                       False
# Unbothered                                  False                       False
# Piano Tiles (Scratch)                       False                       False
#
#                                  GameGenre_Action Platformer  \
# GameName
# ULTRAKILL                                              False
# ROBLOX: Tower Defense Simulator                        False
# Sonic Forces                                           False
# Unbothered                                             False
# Piano Tiles (Scratch)                                  False
#
#                                  GameGenre_Action Puzzler  \
# GameName
# ULTRAKILL                                           False
# ROBLOX: Tower Defense Simulator                     False
# Sonic Forces                                        False
# Unbothered                                          False
# Piano Tiles (Scratch)                               False
#
#                                  GameGenre_Action RPG  \
# GameName
# ULTRAKILL                                       False
# ROBLOX: Tower Defense Simulator                 False
# Sonic Forces                                    False
# Unbothered                                      False
# Piano Tiles (Scratch)                           False
#
#                                  GameGenre_Action-adventure  ...  \
# GameName                                                     ...
# ULTRAKILL                                             False  ...
# ROBLOX: Tower Defense Simulator                       False  ...
# Sonic Forces                                          False  ...
# Unbothered                                            False  ...
# Piano Tiles (Scratch)                                 False  ...
#
#                                  GameGenre_Top-down  GameGenre_Tower defense  \
# GameName
# ULTRAKILL                                     False                    False
# ROBLOX: Tower Defense Simulator               False                     True
# Sonic Forces                                  False                    False
# Unbothered                                    False                    False
# Piano Tiles (Scratch)                         False                    False
#
#                                  GameGenre_Toys-to-life  \
# GameName
# ULTRAKILL                                         False
# ROBLOX: Tower Defense Simulator                   False
# Sonic Forces                                      False
# Unbothered                                        False
# Piano Tiles (Scratch)                             False
#
#                                  GameGenre_Walking Simulator  \
# GameName
# ULTRAKILL                                              False
# ROBLOX: Tower Defense Simulator                        False
# Sonic Forces                                           False
# Unbothered                                             False
# Piano Tiles (Scratch)                                  False
#
#                                  GameGenre_Wholesome  GameGenre_horror game  \
# GameName
# ULTRAKILL                                      False                  False
# ROBLOX: Tower Defense Simulator                False                  False
# Sonic Forces                                   False                  False
# Unbothered                                     False                  False
# Piano Tiles (Scratch)                          False                  False
#
#                                  GameGenre_movement shooter  \
# GameName
# ULTRAKILL                                             False
# ROBLOX: Tower Defense Simulator                       False
# Sonic Forces                                          False
# Unbothered                                            False
# Piano Tiles (Scratch)                                 False
#
#                                  GameGenre_point and click  GameGenre_retro  \
# GameName
# ULTRAKILL                                            False            False
# ROBLOX: Tower Defense Simulator                      False            False
# Sonic Forces                                         False            False
# Unbothered                                           False            False
# Piano Tiles (Scratch)                                False            False
#
#                                      RunTime
# GameName
# ULTRAKILL                         172.413789
# ROBLOX: Tower Defense Simulator  1480.127821
# Sonic Forces                       84.820000
# Unbothered                        229.817000
# Piano Tiles (Scratch)              10.967000
#
# [5 rows x 93 columns]

# %% [markdown]
# ### Compute game-game similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Game similarity matrix
game_similarity = pd.DataFrame(
    cosine_similarity(game_features),
    index=game_features.index,
    columns=game_features.index
)

game_similarity.head()
# Out:
# GameName                         ULTRAKILL  ROBLOX: Tower Defense Simulator  \
# GameName
# ULTRAKILL                         1.000000                         0.999983
# ROBLOX: Tower Defense Simulator   0.999983                         1.000000
# Sonic Forces                      0.999914                         0.999930
# Unbothered                        0.999983                         1.000000
# Piano Tiles (Scratch)             0.999983                         1.000000
#
# GameName                         Sonic Forces  Unbothered  \
# GameName
# ULTRAKILL                            0.999914    0.999983
# ROBLOX: Tower Defense Simulator      0.999930    1.000000
# Sonic Forces                         1.000000    0.999931
# Unbothered                           0.999931    1.000000
# Piano Tiles (Scratch)                0.999931    1.000000
#
# GameName                         Piano Tiles (Scratch)  Red Ball  Bionicle  \
# GameName
# ULTRAKILL                                     0.999983  0.999976  0.999983
# ROBLOX: Tower Defense Simulator               1.000000  0.999993  1.000000
# Sonic Forces                                  0.999931  0.999924  0.999930
# Unbothered                                    1.000000  0.999993  1.000000
# Piano Tiles (Scratch)                         1.000000  0.999993  1.000000
#
# GameName                         Duck Game  ULTRAKILL - Category Extensions  \
# GameName
# ULTRAKILL                         0.996875                         0.999992
# ROBLOX: Tower Defense Simulator   0.996892                         0.999998
# Sonic Forces                      0.996823                         0.999929
# Unbothered                        0.996892                         0.999998
# Piano Tiles (Scratch)             0.996892                         0.999998
#
# GameName                         Escape the Backrooms  ...  Sonic Mania  \
# GameName                                               ...
# ULTRAKILL                                    0.999983  ...     0.999491
# ROBLOX: Tower Defense Simulator              0.999999  ...     0.999508
# Sonic Forces                                 0.999930  ...     0.999808
# Unbothered                                   0.999999  ...     0.999508
# Piano Tiles (Scratch)                        0.999999  ...     0.999508
#
# GameName                         EA Sports UFC 4  EA Sports UFC 3  \
# GameName
# ULTRAKILL                               0.707095         0.707095
# ROBLOX: Tower Defense Simulator         0.707107         0.707107
# Sonic Forces                            0.707058         0.707058
# Unbothered                              0.707107         0.707107
# Piano Tiles (Scratch)                   0.707107         0.707107
#
# GameName                         Accounting+  Hot Lava  Half-Life 2  \
# GameName
# ULTRAKILL                           0.999983  0.999929     0.999992
# ROBLOX: Tower Defense Simulator     1.000000  0.999946     0.999998
# Sonic Forces                        0.999931  0.999876     0.999929
# Unbothered                          1.000000  0.999946     0.999998
# Piano Tiles (Scratch)               1.000000  0.999946     0.999998
#
# GameName                         Clustertruck Category Extensions  COASTLINE  \
# GameName
# ULTRAKILL                                                0.999982   0.999983
# ROBLOX: Tower Defense Simulator                          0.999999   1.000000
# Sonic Forces                                             0.999929   0.999931
# Unbothered                                               0.999999   1.000000
# Piano Tiles (Scratch)                                    0.999999   1.000000
#
# GameName                         Ghostrunner 2  Among Us Clicker
# GameName
# ULTRAKILL                             0.999983          0.998675
# ROBLOX: Tower Defense Simulator       1.000000          0.998692
# Sonic Forces                          0.999931          0.998623
# Unbothered                            1.000000          0.998692
# Piano Tiles (Scratch)                 1.000000          0.998692
#
# [5 rows x 772 columns]

# %% [markdown]
# ### Content-Based Recommender Function

# %%
def recommend_games_content_based(player_id, player_game_matrix, game_similarity, top_n=5):
    if player_id not in player_game_matrix.index:
        return []

    # Games the player already played
    played_games = player_game_matrix.columns[player_game_matrix.loc[player_id] == 1]

    # Score all games by how similar they are to played games
    scores = game_similarity.loc[played_games].sum(axis=0)

    # Remove already played games from recommendations
    scores = scores.drop(played_games, errors='ignore')

    # Get top recommendations
    recommended_games = scores.sort_values(ascending=False).head(top_n).index.tolist()

    return recommended_games

# %%
recommend_games_content_based(
    player_id='18v0n0nx\n',
    player_game_matrix=player_game_matrix,
    game_similarity=game_similarity,
    top_n=5
)
# Out:
# []
